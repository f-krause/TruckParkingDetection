# %%
import pandas as pd

# %%
df = pd.read_csv("osm_data_cars.csv", index_col=0)

# %%
del df["id"]

# %%
df
# Out:
#                           id_new                          pt  \
# 0        47.006201_6.9670316_ts2      (47.006201, 6.9670316)
# 1    39.7880508_-105.0333886_ts2  (39.7880508, -105.0333886)
# 2     41.1745044_-83.4191734_ts2   (41.1745044, -83.4191734)
# 3      4.9431691_114.9351884_ts2    (4.9431691, 114.9351884)
# 4      50.7486297_-1.8496005_ts2    (50.7486297, -1.8496005)
# ..                           ...                         ...
# 614   39.8168989_-86.1564466_ts2   (39.8168989, -86.1564466)
# 615  31.7651862_-106.4570959_ts2  (31.7651862, -106.4570959)
# 616     49.3715495_6.1522216_ts2     (49.3715495, 6.1522216)
# 617       5.345678_-3.949021_ts2       (5.345678, -3.949021)
# 618    50.7482532_-1.8594093_ts2    (50.7482532, -1.8594093)
#
#                                               geometry  \
# 0    POLYGON((6.9670316 47.006201, 6.9668722 47.006...
# 1    POLYGON((-105.0333886 39.7880508, -105.0334789...
# 2    POLYGON((-83.4191734 41.1745044, -83.4191729 4...
# ...

# %%
df.rename(columns = {'id_new':'id'}, inplace = True)

# %%
df
# Out:
#                               id                          pt  \
# 0        47.006201_6.9670316_ts2      (47.006201, 6.9670316)
# 1    39.7880508_-105.0333886_ts2  (39.7880508, -105.0333886)
# 2     41.1745044_-83.4191734_ts2   (41.1745044, -83.4191734)
# 3      4.9431691_114.9351884_ts2    (4.9431691, 114.9351884)
# 4      50.7486297_-1.8496005_ts2    (50.7486297, -1.8496005)
# ..                           ...                         ...
# 614   39.8168989_-86.1564466_ts2   (39.8168989, -86.1564466)
# 615  31.7651862_-106.4570959_ts2  (31.7651862, -106.4570959)
# 616     49.3715495_6.1522216_ts2     (49.3715495, 6.1522216)
# 617       5.345678_-3.949021_ts2       (5.345678, -3.949021)
# 618    50.7482532_-1.8594093_ts2    (50.7482532, -1.8594093)
#
#                                               geometry  \
# 0    POLYGON((6.9670316 47.006201, 6.9668722 47.006...
# 1    POLYGON((-105.0333886 39.7880508, -105.0334789...
# 2    POLYGON((-83.4191734 41.1745044, -83.4191729 4...
# ...

# %%
df.to_csv("osm_data_cars_new.csv")
